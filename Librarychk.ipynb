# %%
from mulfunc import multiplefunc

# %%
multiplefunc.Oddeven()
# Out:
# Enter a number 52452
# 52452 is Even number
# 'Even number'

# %%
multiplefunc.Eligible()
# Out:
# your Gender Male
# Your Age 20
# Not Elegible
# 'Not Elegible'

# %%
multiplefunc.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triange: 544.0
# Height1: 2
# Height2 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10

# %%
multiplefunc.percentage(98,87,95,95,93)
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage: 93.6
# 'Percentage'

# %%
multiplefunc.Subfields()
# Out:
# Sub-fields in AI are:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 multiplefunc.Subfields()
#
# File C:\Hope\AI Course\Python\mulfunc.py:4, in multiplefunc.Subfields()
#       2 def Subfields():
#       3     print("Sub-fields in AI are:")
# ----> 4     for temp in lists:
#       5         print(temp)
#
# NameError: name 'lists' is not defined
